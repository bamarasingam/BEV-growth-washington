# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
#Electric Vehicle Population Data as of today
df = pd.read_csv('../../datasets/Electric_Vehicle_Population_Data.csv')
#https://catalog.data.gov/dataset/electric-vehicle-population-data

# %%
df.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# 1             Not eligible due to low battery range              25
# 2             Not eligible due to low battery range              25
# 3           Clean Alternative Fuel Vehicle Eligible             215
# 4           Clean Alternative Fuel Vehicle Eligible              97
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  43.0       249675142
# 1          0                   1.0       233928502
# 2          0                  14.0       229675939
# 3          0                  45.0       104714466
# 4          0                  22.0       185498386
#
#                   Vehicle Location  \
# 0     POINT (-122.34301 47.659185)
# 1     POINT (-122.20578 47.762405)
# 2  POINT (-120.6027202 46.5965625)
# 3     POINT (-122.209285 47.71124)
# 4     POINT (-122.89692 47.043535)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 2                                     PACIFICORP       5.307700e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10

# %%
df['Model'].value_counts()
# Out:
# MODEL Y        28502
# MODEL 3        27709
# LEAF           13187
# MODEL S         7611
# BOLT EV         5733
#                ...
# 745LE              2
# 918                1
# FLYING SPUR        1
# S-10 PICKUP        1
# BENTAYGA           1
# Name: Model, Length: 127, dtype: int64

# %%
df['Electric Vehicle Type'].value_counts()
# Out:
# Battery Electric Vehicle (BEV)            116807
# Plug-in Hybrid Electric Vehicle (PHEV)     33675
# Name: Electric Vehicle Type, dtype: int64

# %%
#Checking mean electric range for BEV's
df[df['Electric Vehicle Type'] == 'Battery Electric Vehicle (BEV)']['Electric Range'].mean()
# Out:
# 78.60890186375816

# %%
#Mean electric range for PHEV's
df[df['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)']['Electric Range'].mean()
# Out:
# 30.65547141796585

# %%
#Above two numbers seems inaccurate
#Checking amount of 0's for electric range from BEV's
len(df[(df['Electric Range'] == 0) & (df['Electric Vehicle Type'] == 'Battery Electric Vehicle (BEV)')])
# Out:
# 69698

# %%
gg = df[df['Electric Range'] == 0]

gg.head()
# Out:
#     VIN (1-10)  County      City State  Postal Code  Model Year        Make  \
# 9   7SAYGDEF0P    King  Bellevue    WA      98004.0        2023       TESLA
# 34  5YJ3E1EA4P    King  Bellevue    WA      98006.0        2023       TESLA
# 38  1V2DNPE83P    King   Seattle    WA      98125.0        2023  VOLKSWAGEN
# 39  1G1FY6S06N  Yakima    Tieton    WA      98947.0        2022   CHEVROLET
# 54  7SAYGDEE7P    King    Renton    WA      98058.0        2023       TESLA
#
#       Model           Electric Vehicle Type  \
# 9   MODEL Y  Battery Electric Vehicle (BEV)
# 34  MODEL 3  Battery Electric Vehicle (BEV)
# 38     ID.4  Battery Electric Vehicle (BEV)
# 39  BOLT EV  Battery Electric Vehicle (BEV)
# 54  MODEL Y  Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 9   Eligibility unknown as battery range has not b...               0
# 34  Eligibility unknown as battery range has not b...               0
# 38  Eligibility unknown as battery range has not b...               0
# 39  Eligibility unknown as battery range has not b...               0
# 54  Eligibility unknown as battery range has not b...               0
#
#     Base MSRP  Legislative District  DOL Vehicle ID  \
# 9           0                  48.0       240416207
# 34          0                  41.0       241481278
# 38          0                  46.0       245619664
# 39          0                  14.0       208932349
# 54          0                  11.0       251366160
#
#                    Vehicle Location  \
# 9      POINT (-122.201905 47.61385)
# 34     POINT (-122.16937 47.571015)
# 38     POINT (-122.296385 47.71558)
# 39      POINT (-120.75692 46.70383)
# 54  POINT (-122.1298876 47.4451257)
#
#                                  Electric Utility  2020 Census Tract
# 9   PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 34  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 38   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 39                                     PACIFICORP       5.307700e+10
# 54  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10

# %%
gg.shape
# Out:
# (69698, 17)

# %% [markdown]
# Because the electric range seemed so low, I wanted to see how many of them have 0 as an entry. Will have to figure out what I want to do with this, whether deleting these rows/information or filling it in with data from the same model.

# %%
#Going to order by Electric Range in descending order
df = df.sort_values(by = 'Electric Range', ascending = False)

# %%
#Checking to see CAFV Eligibility as so many electric ranges are equal to 0
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
# Out:
# Eligibility unknown as battery range has not been researched    69698
# Clean Alternative Fuel Vehicle Eligible                         62951
# Not eligible due to low battery range                           17833
# Name: Clean Alternative Fuel Vehicle (CAFV) Eligibility, dtype: int64

# %%
#Checking mean for electric vehicles which are eligible
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible']['Electric Range'].mean()
# Out:
# 156.6460262744039

# %%
#Checking mean for electric vehicles which are eligible
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Eligibility unknown as battery range has not been researched']['Electric Range'].mean()
# Out:
# 0.0

# %%
gg = df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Eligibility unknown as battery range has not been researched']

# %%
gg.head()
# Out:
#         VIN (1-10)  County           City State  Postal Code  Model Year  \
# 126262  1G1FX6S08P  Pierce         Tacoma    WA      98422.0        2023
# 110491  7SAYGAEE4P  Island  Camano Island    WA      98282.0        2023
# 130843  7SAXCDE53N    King    Woodinville    WA      98072.0        2022
# 108838  7SAYGDEE6P    King         Auburn    WA      98001.0        2023
# 145010  5YJ3E1EB6N    King        Seattle    WA      98177.0        2022
#
#              Make    Model           Electric Vehicle Type  \
# 126262  CHEVROLET  BOLT EV  Battery Electric Vehicle (BEV)
# 110491      TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130843      TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 108838      TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 145010      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 126262  Eligibility unknown as battery range has not b...               0
# 110491  Eligibility unknown as battery range has not b...               0
# 130843  Eligibility unknown as battery range has not b...               0
# 108838  Eligibility unknown as battery range has not b...               0
# 145010  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 126262          0                  27.0       236513518
# 110491          0                  10.0       229879233
# 130843          0                  45.0       205567267
# 108838          0                  30.0       221374380
# 145010          0                  36.0       196328842
#
#                        Vehicle Location  \
# 126262      POINT (-122.38578 47.28971)
# 110491  POINT (-122.5310901 48.2192797)
# 130843     POINT (-122.151665 47.75855)
# 108838  POINT (-122.2849393 47.3384055)
# 145010     POINT (-122.382425 47.77279)
#
#                                          Electric Utility  2020 Census Tract
# 126262  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305394e+10
# 110491  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
# 130843      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 108838      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 145010       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10

# %%
#Filling in 0's which can be filled based on model, make and model year
df['Electric Range'] = df.groupby(['Model', 'Make', 'Model Year'])['Electric Range'].transform('max')

# %%
df.tail(50)
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 72213   5YJ3E1EC0M      Clark          Yacolt    WA      98675.0        2021
# 72211   KNDCR3L15P       King         Seattle    WA      98117.0        2023
# 72206   WMW13DJ06N       King         Seattle    WA      98125.0        2022
# 5036    7SAXCAE58P    Clallam          Sequim    WA      98382.0        2023
# 72155   5YJYGDEE1M       King         Kenmore    WA      98028.0        2021
# 72154   1N4AZ1BV8N  Snohomish    Lake Stevens    WA      98258.0        2022
# 72153   YV4ED3UB8N       King         Seattle    WA      98126.0        2022
# 72152   5YJ3E1EA2M       King         Seattle    WA      98105.0        2021
# 72110   3FMTK1RM1N       King         Seattle    WA      98116.0        2022
# 72109   7SAYGAEE1P       King         Seattle    WA      98133.0        2023
# 72104   YV4ED3UR0N       King       Shoreline    WA      98155.0        2022
# 5045    3FMTK3SU4M       King        Bellevue    WA      98006.0        2021
# 72098   5YJ3E1EA7M       King          Auburn    WA      98092.0        2021
# 72095   5YJYGAEE0M       King          Medina    WA      98039.0        2021
# 72090   1G1FZ6S02M       King         Seattle    WA      98115.0        2021
# 72087   KM8KNDAFXP       King         Seattle    WA      98115.0        2023
# 72083   7FCTGAAL0N       King        Kirkland    WA      98034.0        2022
# 72081   5YJSA1E51N      Clark           Camas    WA      98607.0        2022
# 5046    7SAYGDEE8P       King            Kent    WA      98042.0        2023
# 72073   7SAYGDEE9P       King         Seattle    WA      98117.0        2023
# 72072   7SAYGDEEXN       King       Newcastle    WA      98056.0        2022
# 72067   WBY43AW0XP       King         Seattle    WA      98109.0        2023
# 72064   7SAYGDEE8P     Pierce          Tacoma    WA      98406.0        2023
# 72063   1N4CZ1CV9P       King         Seattle    WA      98117.0        2023
# 72059   7SAYGDEE2P   Thurston           Lacey    WA      98516.0        2023
# 72057   7SAYGDEE4P       King         Seattle    WA      98103.0        2023
# 5048    3FMTK3SU7M       King        Bellevue    WA      98006.0        2021
# 72111   WVGUNPE20M    Spokane  Spokane Valley    WA      99206.0        2021
# 72114   5YJ3E1EB2N       King        Issaquah    WA      98029.0        2022
# 72115   5YJ3E1EA5M       King         Seattle    WA      98103.0        2021
# 72137   JTMABABA7P       King         Bothell    WA      98011.0        2023
# 72151   5YJ3E1EB1M     Pierce        Lakewood    WA      98498.0        2021
# 5043    WAUEJBFW5N       King         Seattle    WA      98144.0        2022
# 72146   WVGTMPE22M       King         Seattle    WA      98118.0        2021
# 72145   5YJYGDEE2M       King       Sammamish    WA      98075.0        2021
# 72143   1FTBW9CK5N  Snohomish          Sultan    WA      98294.0        2022
# 72142   3FMTK4SE8N  Snohomish         Edmonds    WA      98020.0        2022
# 72141   5YJ3E1EC2P       King        Kirkland    WA      98033.0        2023
# 72139   1GYKPMRL1R       King         Seattle    WA      98102.0        2024
# 72136   7FCTGAAL8N      Clark       Vancouver    WA      98661.0        2022
# 5044    WBY73AW03P       King         Tukwila    WA      98168.0        2023
# 72134   5YJSA1E68M       King   Mercer Island    WA      98040.0        2021
# 72133   KNDC3DLC8N       King          Renton    WA      98059.0        2022
# 72132   3FMTK2SU1P       King         Seattle    WA      98108.0        2023
# 72131   7SAYGDEE3P     Kitsap       Bremerton    WA      98312.0        2023
# 72130   7SAXCBE62N       King          Renton    WA      98059.0        2022
# 72124   WMW13DJ04P       King   Mercer Island    WA      98040.0        2023
# 72123   1V2GNPE83P       King      Des Moines    WA      98198.0        2023
# 72120   7SAXCAE55N       King        Bellevue    WA      98004.0        2022
# 150481  7SAYGDEF8N     Skagit    Mount Vernon    WA      98273.0        2022
#
#               Make           Model           Electric Vehicle Type  \
# 72213        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72211          KIA            NIRO  Battery Electric Vehicle (BEV)
# 72206         MINI         HARDTOP  Battery Electric Vehicle (BEV)
# 5036         TESLA         MODEL X  Battery Electric Vehicle (BEV)
# 72155        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72154       NISSAN            LEAF  Battery Electric Vehicle (BEV)
# 72153        VOLVO            XC40  Battery Electric Vehicle (BEV)
# 72152        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72110         FORD  MUSTANG MACH-E  Battery Electric Vehicle (BEV)
# 72109        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72104        VOLVO            XC40  Battery Electric Vehicle (BEV)
# 5045          FORD  MUSTANG MACH-E  Battery Electric Vehicle (BEV)
# 72098        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72095        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72090    CHEVROLET         BOLT EV  Battery Electric Vehicle (BEV)
# 72087      HYUNDAI         IONIQ 5  Battery Electric Vehicle (BEV)
# 72083       RIVIAN             R1T  Battery Electric Vehicle (BEV)
# 72081        TESLA         MODEL S  Battery Electric Vehicle (BEV)
# 5046         TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72073        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72072        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72067          BMW              I4  Battery Electric Vehicle (BEV)
# 72064        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72063       NISSAN            LEAF  Battery Electric Vehicle (BEV)
# 72059        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72057        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 5048          FORD  MUSTANG MACH-E  Battery Electric Vehicle (BEV)
# 72111   VOLKSWAGEN            ID.4  Battery Electric Vehicle (BEV)
# 72114        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72115        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72137       SUBARU        SOLTERRA  Battery Electric Vehicle (BEV)
# 72151        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 5043          AUDI       E-TRON GT  Battery Electric Vehicle (BEV)
# 72146   VOLKSWAGEN            ID.4  Battery Electric Vehicle (BEV)
# 72145        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72143         FORD         TRANSIT  Battery Electric Vehicle (BEV)
# 72142         FORD  MUSTANG MACH-E  Battery Electric Vehicle (BEV)
# 72141        TESLA         MODEL 3  Battery Electric Vehicle (BEV)
# 72139     CADILLAC           LYRIQ  Battery Electric Vehicle (BEV)
# 72136       RIVIAN             R1T  Battery Electric Vehicle (BEV)
# 5044           BMW              I4  Battery Electric Vehicle (BEV)
# 72134        TESLA         MODEL S  Battery Electric Vehicle (BEV)
# 72133          KIA             EV6  Battery Electric Vehicle (BEV)
# 72132         FORD  MUSTANG MACH-E  Battery Electric Vehicle (BEV)
# 72131        TESLA         MODEL Y  Battery Electric Vehicle (BEV)
# 72130        TESLA         MODEL X  Battery Electric Vehicle (BEV)
# 72124         MINI         HARDTOP  Battery Electric Vehicle (BEV)
# 72123   VOLKSWAGEN            ID.4  Battery Electric Vehicle (BEV)
# 72120        TESLA         MODEL X  Battery Electric Vehicle (BEV)
# 150481       TESLA         MODEL Y  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 72213   Eligibility unknown as battery range has not b...               0
# 72211   Eligibility unknown as battery range has not b...              33
# 72206   Eligibility unknown as battery range has not b...               0
# 5036    Eligibility unknown as battery range has not b...               0
# 72155   Eligibility unknown as battery range has not b...               0
# 72154   Eligibility unknown as battery range has not b...               0
# 72153   Eligibility unknown as battery range has not b...               0
# 72152   Eligibility unknown as battery range has not b...               0
# 72110   Eligibility unknown as battery range has not b...               0
# 72109   Eligibility unknown as battery range has not b...               0
# 72104   Eligibility unknown as battery range has not b...               0
# 5045    Eligibility unknown as battery range has not b...               0
# 72098   Eligibility unknown as battery range has not b...               0
# 72095   Eligibility unknown as battery range has not b...               0
# 72090   Eligibility unknown as battery range has not b...               0
# 72087   Eligibility unknown as battery range has not b...               0
# 72083   Eligibility unknown as battery range has not b...               0
# 72081   Eligibility unknown as battery range has not b...               0
# 5046    Eligibility unknown as battery range has not b...               0
# 72073   Eligibility unknown as battery range has not b...               0
# 72072   Eligibility unknown as battery range has not b...               0
# 72067   Eligibility unknown as battery range has not b...               0
# 72064   Eligibility unknown as battery range has not b...               0
# 72063   Eligibility unknown as battery range has not b...               0
# 72059   Eligibility unknown as battery range has not b...               0
# 72057   Eligibility unknown as battery range has not b...               0
# 5048    Eligibility unknown as battery range has not b...               0
# 72111   Eligibility unknown as battery range has not b...               0
# 72114   Eligibility unknown as battery range has not b...               0
# 72115   Eligibility unknown as battery range has not b...               0
# 72137   Eligibility unknown as battery range has not b...               0
# 72151   Eligibility unknown as battery range has not b...               0
# 5043    Eligibility unknown as battery range has not b...               0
# 72146   Eligibility unknown as battery range has not b...               0
# 72145   Eligibility unknown as battery range has not b...               0
# 72143   Eligibility unknown as battery range has not b...               0
# 72142   Eligibility unknown as battery range has not b...               0
# 72141   Eligibility unknown as battery range has not b...               0
# 72139   Eligibility unknown as battery range has not b...               0
# 72136   Eligibility unknown as battery range has not b...               0
# 5044    Eligibility unknown as battery range has not b...               0
# 72134   Eligibility unknown as battery range has not b...               0
# 72133   Eligibility unknown as battery range has not b...               0
# 72132   Eligibility unknown as battery range has not b...               0
# 72131   Eligibility unknown as battery range has not b...               0
# 72130   Eligibility unknown as battery range has not b...               0
# 72124   Eligibility unknown as battery range has not b...               0
# 72123   Eligibility unknown as battery range has not b...               0
# 72120   Eligibility unknown as battery range has not b...               0
# 150481  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 72213           0                  18.0       166416645
# 72211           0                  36.0       235190875
# 72206           0                  46.0       193280272
# 5036            0                  24.0       224415033
# 72155           0                  46.0       161394229
# 72154           0                  44.0       197564692
# 72153           0                  34.0       207291171
# 72152           0                  43.0       180587683
# 72110           0                  34.0       228008196
# 72109           0                  32.0       225890367
# 72104           0                  32.0       179134546
# 5045            0                  41.0       168744614
# 72098           0                  31.0       179751393
# 72095           0                  48.0       171359625
# 72090           0                  46.0       187400349
# 72087           0                  43.0       245168780
# 72083           0                  45.0       220476847
# 72081           0                  18.0       209643948
# 5046            0                  47.0       224432603
# 72073           0                  36.0       236429098
# 72072           0                  41.0       220803873
# 72067           0                  36.0       241293405
# 72064           0                  27.0       244330082
# 72063           0                  36.0       226075097
# 72059           0                  22.0       245778459
# 72057           0                  43.0       251579345
# 5048            0                  41.0       148553982
# 72111           0                   4.0       187047444
# 72114           0                   5.0       186539489
# 72115           0                  46.0       177832406
# 72137           0                   1.0       233011957
# 72151           0                  28.0       151294314
# 5043            0                  37.0       214724408
# 72146           0                  37.0       182938794
# 72145           0                  41.0       168563398
# 72143           0                  39.0       207414749
# 72142           0                  21.0       200522843
# 72141           0                  48.0       225733462
# 72139           0                  43.0       251621541
# 72136           0                  49.0       233607867
# 5044            0                  11.0       228529073
# 72134           0                  41.0       183302192
# 72133           0                  11.0       212371106
# 72132           0                  11.0       228656046
# 72131           0                  35.0       238913524
# 72130           0                  11.0       218118813
# 72124           0                  41.0       220285131
# 72123           0                  33.0       228313354
# 72120           0                  48.0       219401367
# 150481          0                  40.0       207667589
#
#                        Vehicle Location  \
# 72213   POINT (-122.4066726 45.8651816)
# 72211       POINT (-122.37275 47.68968)
# 72206      POINT (-122.296385 47.71558)
# 5036       POINT (-123.105015 48.08104)
# 72155   POINT (-122.2504747 47.7617128)
# 72154       POINT (-122.112265 48.0047)
# 72153       POINT (-122.37439 47.54468)
# 72152      POINT (-122.319115 47.66132)
# 72110       POINT (-122.38679 47.56484)
# 72109       POINT (-122.34584 47.76726)
# 72104      POINT (-122.3175 47.7578146)
# 5045       POINT (-122.16937 47.571015)
# 72098   POINT (-122.1820969 47.3198995)
# 72095      POINT (-122.228025 47.61598)
# 72090        POINT (-122.3185 47.67949)
# 72087        POINT (-122.3185 47.67949)
# 72083      POINT (-122.209285 47.71124)
# 72081      POINT (-122.405565 45.59009)
# 5046       POINT (-122.111625 47.36078)
# 72073       POINT (-122.37275 47.68968)
# 72072     POINT (-122.180505 47.500055)
# 72067      POINT (-122.34848 47.632405)
# 72064      POINT (-122.490985 47.26365)
# 72063       POINT (-122.37275 47.68968)
# 72059     POINT (-122.7510253 47.08149)
# 72057      POINT (-122.34301 47.659185)
# 5048       POINT (-122.16937 47.571015)
# 72111   POINT (-117.2459114 47.6525293)
# 72114     POINT (-121.999595 47.547635)
# 72115      POINT (-122.34301 47.659185)
# 72137      POINT (-122.20578 47.762405)
# 72151     POINT (-122.547645 47.176685)
# 5043       POINT (-122.30823 47.581975)
# 72146      POINT (-122.28339 47.549285)
# 72145       POINT (-122.03309 47.58153)
# 72143     POINT (-121.814825 47.868195)
# 72142       POINT (-122.37507 47.80807)
# 72141        POINT (-122.20264 47.6785)
# 72139   POINT (-122.3223156 47.6402108)
# 72136     POINT (-122.641835 45.638545)
# 5044         POINT (-122.286465 47.476)
# 72134    POINT (-122.2377542 47.582905)
# 72133      POINT (-122.15734 47.487175)
# 72132      POINT (-122.326965 47.55015)
# 72131       POINT (-122.65223 47.57192)
# 72130      POINT (-122.15734 47.487175)
# 72124    POINT (-122.2377542 47.582905)
# 72123   POINT (-122.3219166 47.4013897)
# 72120      POINT (-122.201905 47.61385)
# 150481     POINT (-122.338975 48.41333)
#
#                                          Electric Utility  2020 Census Tract
# 72213   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10
# 72211        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72206        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 5036    BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.300900e+10
# 72155       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72154                              PUGET SOUND ENERGY INC       5.306105e+10
# 72153        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72152        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72110        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72109        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72104        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303302e+10
# 5045        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72098       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72095       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72090        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72087        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72083       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72081   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10
# 5046        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72073        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72072       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72067        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72064   BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 72063        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72059                              PUGET SOUND ENERGY INC       5.306701e+10
# 72057        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 5048        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72111   BONNEVILLE POWER ADMINISTRATION||VERA IRRIGATI...       5.306301e+10
# 72114       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72115        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 72137       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72151       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 5043         CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72146       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303301e+10
# 72145       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72143                              PUGET SOUND ENERGY INC       5.306105e+10
# 72142                              PUGET SOUND ENERGY INC       5.306105e+10
# 72141       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72139        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72136   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10
# 5044         CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303303e+10
# 72134       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72133       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72132        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 72131                              PUGET SOUND ENERGY INC       5.303508e+10
# 72130       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72124       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 72123       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 72120       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 150481                             PUGET SOUND ENERGY INC       5.305795e+10

# %%
df[df['Electric Range'] == 0].shape
# Out:
# (68452, 17)

# %%
#Going to remove anything where the electric range is 0
df = df[df['Electric Range'] != 0]
df.shape
# Out:
# (82030, 17)

# %%
#Checking mean electric range for BEV's after 0's dropped
df[df['Electric Vehicle Type'] == 'Battery Electric Vehicle (BEV)']['Electric Range'].mean()
# Out:
# 193.99278254575535

# %%
#Mean electric range for PHEV's after 0's dropped
df[df['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)']['Electric Range'].mean()
# Out:
# 33.851878247958425

# %%
#Checking mean for Clean Alternative Fuel Vehicle Eligible
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible']['Electric Range'].mean()
# Out:
# 158.7880732633318

# %%
#Reading in original dataset in case need to use again
df_og = pd.read_csv('../../datasets/Electric_Vehicle_Population_Data.csv')

# %%
df_og['Make'].value_counts()
# Out:
# TESLA                   68983
# NISSAN                  13497
# CHEVROLET               12026
# FORD                     7614
# BMW                      6439
# KIA                      6198
# TOYOTA                   5223
# VOLKSWAGEN               4074
# VOLVO                    3536
# JEEP                     3292
# HYUNDAI                  3171
# AUDI                     3006
# CHRYSLER                 2642
# RIVIAN                   2483
# MERCEDES-BENZ            1054
# PORSCHE                  1028
# MITSUBISHI                849
# HONDA                     810
# FIAT                      806
# MINI                      791
# POLESTAR                  764
# SUBARU                    623
# SMART                     274
# LINCOLN                   229
# JAGUAR                    228
# LUCID                     190
# CADILLAC                  176
# LEXUS                     138
# MAZDA                     136
# GENESIS                   107
# LAND ROVER                 47
# FISKER                     17
# ALFA ROMEO                 12
# AZURE DYNAMICS              9
# TH!NK                       5
# WHEEGO ELECTRIC CARS        3
# BENTLEY                     2
# Name: Make, dtype: int64

# %%
#Create a bar chart based on Make of car
makes = df_og['Make'].value_counts()
plt.bar(makes.index, makes.values)
plt.xticks(rotation = 90)
plt.title('Total Cars per Make')
plt.xlabel('Brand')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
#Pie chart for distribution of car makes
# Creating others for those less than 3%
others = makes[makes >= 0.03 * makes.sum()]
others['Other'] = makes[makes < 0.03 * makes.sum()].sum()

# Create a pie chart
plt.pie(others.values, labels=others.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  

plt.title('Distrbution of Car Makes')
plt.show()
