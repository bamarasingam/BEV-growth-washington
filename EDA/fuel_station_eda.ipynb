# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
fuel_stations = pd.read_csv('../../datasets/alt_fuel_stations.csv')
#https://afdc.energy.gov/stations/#/analyze
fuel_stations.head()
# Out:
# /var/folders/v1/kyy1qs715rbg2rqbmr3z3rb40000gn/T/ipykernel_45277/934424578.py:1: DtypeWarning: Columns (14,15,16,20,31,33,34,39,41,43,46,49,52,57,58,59,60,61,62,65,67,69,70,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   fuel_stations = pd.read_csv('../../datasets/alt_fuel_stations.csv')
#   Fuel Type Code                                Station Name  \
# 0            CNG                  Arkansas Oklahoma Gas Corp
# 1            CNG  Clean Energy - Logan International Airport
# 2            CNG      Clean Energy - Everett - National Grid
# 3            CNG   Clean Energy - Greenpoint - National Grid
# 4            CNG                    Canarsie - National Grid
#
#         Street Address                            Intersection Directions  \
# 0    2100 S Waldron Rd                                                NaN
# 1  1000 Cottage St Ext  From Route 1, take the first exit after Callah...
# 2          16 Rover St  Rt 16, exit to Rt 99, to Dexter St to Rover. O...
# 3      287 Maspeth Ave  I-278/Brooklyn Queens Expy, exit onto Vandervo...
# 4      8424 Ditmas Ave  From Shore Pkwy, take Rockaway Pkwy N, left on...
#
#           City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0   Fort Smith    AR  72903    NaN  479-783-3181           E  ...
# 1  East Boston    MA  02128    NaN  866-809-4869           E  ...
# 2      Everett    MA  02149    NaN  866-809-4869           E  ...
# 3     Brooklyn    NY  11211    NaN  866-809-4869           E  ...
# 4     Brooklyn    NY  11236    NaN  866-809-4869           E  ...
#
#    Restricted Access RD Blends RD Blends (French) RD Blended with Biodiesel  \
# 0              False       NaN                NaN                       NaN
# 1              False       NaN                NaN                       NaN
# 2              False       NaN                NaN                       NaN
# 3              False       NaN                NaN                       NaN
# 4              False       NaN                NaN                       NaN
#
#   RD Maximum Biodiesel Level NPS Unit Name  \
# 0                        NaN           NaN
# 1                        NaN           NaN
# 2                        NaN           NaN
# 3                        NaN           NaN
# 4                        NaN           NaN
#
#   CNG Station Sells Renewable Natural Gas  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                     NaN
#
#    LNG Station Sells Renewable Natural Gas  Maximum Vehicle Class  \
# 0                                      NaN                     MD
# 1                                      NaN                     MD
# 2                                      NaN                     HD
# 3                                      NaN                     HD
# 4                                      NaN                     MD
#
#    EV Workplace Charging
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 74 columns]

# %%
df = fuel_stations[fuel_stations['State'] == 'WA']

# %%
df.shape
# Out:
# (2042, 74)

# %%
df['Fuel Type Code'].value_counts()
# Out:
# ELEC    1984
# LPG       46
# CNG        4
# E85        4
# BD         3
# LNG        1
# Name: Fuel Type Code, dtype: int64

# %%
#Need to filter df to only include ELEC for Fuel Type Code
df = df[df['Fuel Type Code'] == 'ELEC']

# %%
df.shape
# Out:
# (1984, 74)

# %%
df.head(20)
# Out:
#      Fuel Type Code                       Station Name         Street Address  \
# 1251           ELEC  City of Lacey - City Hall Parking         420 College St
# 1554           ELEC                        Avista Corp     1411 E Mission Ave
# 1555           ELEC                Steam Plant Parking          130 S Post St
# 1758           ELEC             BELLEVUE BELLEVUE CH 1       450 110th Ave NE
# 1799           ELEC     KING COUNTY DES ISSAQUAH P&R 2   1755 Highlands Dr NE
# 1843           ELEC    UWB CASCADIA CC NORTH LEVEL 3 N    18500 Campus Way NE
# 1844           ELEC     CITY OF REDMOND CITY HALL DUAL       15670 NE 85th St
# 1845           ELEC      CITY OF REDMOND MOC #1 PUBLIC       18080 NE 76th St
# 1957           ELEC                  Bellingham Nissan           1516 Iowa St
# 1958           ELEC                   Advantage Nissan  5101 Auto Center Blvd
# 1959           ELEC                      Burien Nissan        16042 1st Ave S
# 1960           ELEC             Campbell-Nelson Nissan       24325 Highway 99
# 1961           ELEC                     Olympia Nissan    2220 Carriage Dr SW
# 1962           ELEC              Bill Robertson Nissan         928 N 28th Ave
# 1963           ELEC                  Dan Wilder Nissan           53 Jetta Way
# 1964           ELEC       Bill Korum's Puyallup Nissan      101 Valley Ave NW
# 1965           ELEC                     Younker Nissan       3401 E Valley Rd
# 1966           ELEC                      Wendle Nissan     9000 N Division St
# 1967           ELEC        Dave Smith Nissan - Spokane     6901 E Sprague Ave
# 1968           ELEC                      Tacoma Nissan      4030 S Tacoma Way
#
#                     Intersection Directions            City State    ZIP  \
# 1251  At 3rd Ave SE, next to police station           Lacey    WA  98503
# 1554                                    NaN         Spokane    WA  99252
# 1555                                    NaN         Spokane    WA  99201
# 1758                                    NaN        Bellevue    WA  98004
# 1799                                    NaN        Issaquah    WA  98027
# 1843                                    NaN         Bothell    WA  98011
# 1844                                    NaN         Redmond    WA  98052
# 1845                                    NaN         Redmond    WA  98052
# 1957                                    NaN      Bellingham    WA  98229
# 1958                                    NaN       Bremerton    WA  98312
# 1959                                    NaN          Burien    WA  98148
# 1960                                    NaN         Edmonds    WA  98026
# 1961                                    NaN         Olympia    WA  98502
# 1962                                    NaN           Pasco    WA  99301
# 1963                                    NaN    Port Angeles    WA  98362
# 1964                                    NaN        Puyallup    WA  98371
# 1965                                    NaN          Renton    WA  98058
# 1966                                    NaN         Spokane    WA  99218
# 1967                                    NaN  Spokane Valley    WA  99212
# 1968                                    NaN          Tacoma    WA  98409
#
#       Plus4 Station Phone Status Code  ...  Restricted Access RD Blends  \
# 1251    NaN  360-491-3214           E  ...              False       NaN
# 1554    NaN  509-489-0500           E  ...              False       NaN
# 1555    NaN  800-227-9187           E  ...              False       NaN
# 1758    NaN  888-758-4389           E  ...                NaN       NaN
# 1799    NaN  888-758-4389           E  ...                NaN       NaN
# 1843    NaN  888-758-4389           E  ...                NaN       NaN
# 1844    NaN  888-758-4389           E  ...                NaN       NaN
# 1845    NaN  888-758-4389           E  ...                NaN       NaN
# 1957    NaN  360-733-7300           E  ...              False       NaN
# 1958    NaN  360-373-6300           E  ...              False       NaN
# 1959    NaN  206-242-7070           E  ...              False       NaN
# 1960    NaN           NaN           E  ...              False       NaN
# 1961    NaN  360-352-8558           E  ...              False       NaN
# 1962    NaN  509-545-3000           E  ...              False       NaN
# 1963    NaN  360-452-9268           E  ...              False       NaN
# 1964    NaN  253-848-4507           E  ...              False       NaN
# 1965    NaN           NaN           E  ...              False       NaN
# 1966    NaN  509-468-9000           E  ...              False       NaN
# 1967    NaN  509-924-6242           E  ...              False       NaN
# 1968    NaN  253-473-6200           E  ...              False       NaN
#
#      RD Blends (French) RD Blended with Biodiesel RD Maximum Biodiesel Level  \
# 1251                NaN                       NaN                        NaN
# 1554                NaN                       NaN                        NaN
# 1555                NaN                       NaN                        NaN
# 1758                NaN                       NaN                        NaN
# 1799                NaN                       NaN                        NaN
# 1843                NaN                       NaN                        NaN
# 1844                NaN                       NaN                        NaN
# 1845                NaN                       NaN                        NaN
# 1957                NaN                       NaN                        NaN
# 1958                NaN                       NaN                        NaN
# 1959                NaN                       NaN                        NaN
# 1960                NaN                       NaN                        NaN
# 1961                NaN                       NaN                        NaN
# 1962                NaN                       NaN                        NaN
# 1963                NaN                       NaN                        NaN
# 1964                NaN                       NaN                        NaN
# 1965                NaN                       NaN                        NaN
# 1966                NaN                       NaN                        NaN
# 1967                NaN                       NaN                        NaN
# 1968                NaN                       NaN                        NaN
#
#      NPS Unit Name CNG Station Sells Renewable Natural Gas  \
# 1251           NaN                                     NaN
# 1554           NaN                                     NaN
# 1555           NaN                                     NaN
# 1758           NaN                                     NaN
# 1799           NaN                                     NaN
# 1843           NaN                                     NaN
# 1844           NaN                                     NaN
# 1845           NaN                                     NaN
# 1957           NaN                                     NaN
# 1958           NaN                                     NaN
# 1959           NaN                                     NaN
# 1960           NaN                                     NaN
# 1961           NaN                                     NaN
# 1962           NaN                                     NaN
# 1963           NaN                                     NaN
# 1964           NaN                                     NaN
# 1965           NaN                                     NaN
# 1966           NaN                                     NaN
# 1967           NaN                                     NaN
# 1968           NaN                                     NaN
#
#       LNG Station Sells Renewable Natural Gas  Maximum Vehicle Class  \
# 1251                                      NaN                     LD
# 1554                                      NaN                     LD
# 1555                                      NaN                     LD
# 1758                                      NaN                    NaN
# 1799                                      NaN                    NaN
# 1843                                      NaN                    NaN
# 1844                                      NaN                    NaN
# 1845                                      NaN                    NaN
# 1957                                      NaN                    NaN
# 1958                                      NaN                    NaN
# 1959                                      NaN                     LD
# 1960                                      NaN                    NaN
# 1961                                      NaN                     LD
# 1962                                      NaN                    NaN
# 1963                                      NaN                     LD
# 1964                                      NaN                     LD
# 1965                                      NaN                     LD
# 1966                                      NaN                    NaN
# 1967                                      NaN                     LD
# 1968                                      NaN                     LD
#
#       EV Workplace Charging
# 1251                  False
# 1554                  False
# 1555                  False
# 1758                  False
# 1799                  False
# 1843                  False
# 1844                  False
# 1845                  False
# 1957                  False
# 1958                  False
# 1959                  False
# 1960                  False
# 1961                  False
# 1962                  False
# 1963                  False
# 1964                  False
# 1965                  False
# 1966                  False
# 1967                  False
# 1968                  False
#
# [20 rows x 74 columns]

# %%
df = df.sort_values(by = 'City')
df.head(10)
# Out:
#       Fuel Type Code                           Station Name  \
# 76448           ELEC                     West Valley School
# 68531           ELEC                    WADOC ABERDEEN FO 2
# 40515           ELEC            Walmart 2037 (Aberdeen, WA)
# 62140           ELEC  415 West Heron Street (US-3HE-7VZ-1C)
# 61739           ELEC  415 West Heron Street (US-3HE-7VZ-2C)
# 61738           ELEC  415 West Heron Street (US-3HE-7VZ-2B)
# 61737           ELEC  415 West Heron Street (US-3HE-7VZ-2A)
# 61736           ELEC  415 West Heron Street (US-3HE-7VZ-1B)
# 11415           ELEC      Aberdeen, WA - Tesla Supercharger
# 68532           ELEC                    WADOC ABERDEEN FO 1
#
#               Street Address Intersection Directions                  City  \
# 76448   8900 E. Buckeye Ave.                     NaN  8900 E. Buckeye Ave.
# 68531       304 W Wishkah St                     NaN              Aberdeen
# 40515       909 E Wishkah St                     NaN              Aberdeen
# 62140  415 West Heron Street                     NaN              Aberdeen
# 61739  415 West Heron Street                     NaN              Aberdeen
# 61738  415 West Heron Street                     NaN              Aberdeen
# 61737  415 West Heron Street                     NaN              Aberdeen
# 61736  415 West Heron Street                     NaN              Aberdeen
# 11415     416 Wishkah Street                     NaN              Aberdeen
# 68532       304 W Wishkah St                     NaN              Aberdeen
#
#       State    ZIP  Plus4 Station Phone Status Code  ...  Restricted Access  \
# 76448    WA  99212    NaN  866-816-7584           E  ...                NaN
# 68531    WA  98520    NaN  888-758-4389           E  ...                NaN
# 40515    WA  98520    NaN  833-632-2778           E  ...                NaN
# 62140    WA  98520    NaN  866-576-1495           E  ...                NaN
# 61739    WA  98520    NaN  866-576-1495           E  ...                NaN
# 61738    WA  98520    NaN  866-576-1495           E  ...                NaN
# 61737    WA  98520    NaN  866-576-1495           E  ...                NaN
# 61736    WA  98520    NaN  866-576-1495           E  ...                NaN
# 11415    WA  98520    NaN  877-798-3752           E  ...                NaN
# 68532    WA  98520    NaN  888-758-4389           E  ...                NaN
#
#       RD Blends RD Blends (French) RD Blended with Biodiesel  \
# 76448       NaN                NaN                       NaN
# 68531       NaN                NaN                       NaN
# 40515       NaN                NaN                       NaN
# 62140       NaN                NaN                       NaN
# 61739       NaN                NaN                       NaN
# 61738       NaN                NaN                       NaN
# 61737       NaN                NaN                       NaN
# 61736       NaN                NaN                       NaN
# 11415       NaN                NaN                       NaN
# 68532       NaN                NaN                       NaN
#
#       RD Maximum Biodiesel Level NPS Unit Name  \
# 76448                        NaN           NaN
# 68531                        NaN           NaN
# 40515                        NaN           NaN
# 62140                        NaN           NaN
# 61739                        NaN           NaN
# 61738                        NaN           NaN
# 61737                        NaN           NaN
# 61736                        NaN           NaN
# 11415                        NaN           NaN
# 68532                        NaN           NaN
#
#       CNG Station Sells Renewable Natural Gas  \
# 76448                                     NaN
# 68531                                     NaN
# 40515                                     NaN
# 62140                                     NaN
# 61739                                     NaN
# 61738                                     NaN
# 61737                                     NaN
# 61736                                     NaN
# 11415                                     NaN
# 68532                                     NaN
#
#        LNG Station Sells Renewable Natural Gas  Maximum Vehicle Class  \
# 76448                                      NaN                    NaN
# 68531                                      NaN                    NaN
# 40515                                      NaN                    NaN
# 62140                                      NaN                    NaN
# 61739                                      NaN                    NaN
# 61738                                      NaN                    NaN
# 61737                                      NaN                    NaN
# 61736                                      NaN                    NaN
# 11415                                      NaN                    NaN
# 68532                                      NaN                    NaN
#
#        EV Workplace Charging
# 76448                  False
# 68531                  False
# 40515                  False
# 62140                  False
# 61739                  False
# 61738                  False
# 61737                  False
# 61736                  False
# 11415                  False
# 68532                  False
#
# [10 rows x 74 columns]
