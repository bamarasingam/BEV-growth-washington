# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
#Electric Vehicle Population Data as of today
ev_pop_data = pd.read_csv('datasets_unused/Electric_Vehicle_Population_Data.csv')
#https://catalog.data.gov/dataset/electric-vehicle-population-data

# %%
ev_pop_data.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
ev_pop_data.shape
# Out:
# (150482, 17)

# %%
fuel_stations = pd.read_csv('datasets/alt_fuel_stations.csv')
#https://afdc.energy.gov/stations/#/analyze
fuel_stations.head()
# Out:
# /var/folders/v1/kyy1qs715rbg2rqbmr3z3rb40000gn/T/ipykernel_30074/3849247855.py:1: DtypeWarning: Columns (14,15,16,20,31,33,34,39,41,43,46,49,52,57,58,59,60,61,62,65,67,69,70,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   fuel_stations = pd.read_csv('datasets/alt_fuel_stations.csv')
#   Fuel Type Code                                Station Name  \
# 0            CNG                  Arkansas Oklahoma Gas Corp
# 1            CNG  Clean Energy - Logan International Airport
# 2            CNG      Clean Energy - Everett - National Grid
# 3            CNG   Clean Energy - Greenpoint - National Grid
# 4            CNG                    Canarsie - National Grid
#
#         Street Address                            Intersection Directions  \
# 0    2100 S Waldron Rd                                                NaN
# 1  1000 Cottage St Ext  From Route 1, take the first exit after Callah...
# ...

# %%
df = fuel_stations[fuel_stations['State'] == 'WA']

# %%
df.shape
# Out:
# (2042, 74)

# %%
df['Fuel Type Code'].value_counts()
# Out:
# ELEC    1984
# LPG       46
# CNG        4
# E85        4
# BD         3
# LNG        1
# Name: Fuel Type Code, dtype: int64

# %%
#Need to filter df to only include ELEC for Fuel Type Code
df = fuel_stations[fuel_stations['Fuel Type Code'] == 'ELEC']

# %%
df.head()
# Out:
#    Fuel Type Code                    Station Name           Street Address  \
# 82           ELEC   Los Angeles Convention Center       1201 S Figueroa St
# 83           ELEC  California Air Resources Board         9530 Telstar Ave
# 85           ELEC          Scripps Green Hospital  10666 N Torrey Pines Rd
# 86           ELEC                   Galpin Motors        15421 Roscoe Blvd
# 87           ELEC               Galleria at Tyler   1299 Galleria at Tyler
#
#                Intersection Directions         City State    ZIP  Plus4  \
# 82            West hall and South hall  Los Angeles    CA  90015    NaN
# 83                                 NaN     El Monte    CA  91731    NaN
# 85  Patient Parking Structure, level G     La Jolla    CA  92037    NaN
# 86                                 NaN    Sepulveda    CA  91343    NaN
# 87                                 NaN    Riverside    CA  92503    NaN
#
#    Station Phone Status Code  ...  Restricted Access RD Blends  \
# ...
