# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
#Electric Vehicle Population Data as of today
ev_pop_data = pd.read_csv('datasets/Electric_Vehicle_Population_Data.csv')
#https://catalog.data.gov/dataset/electric-vehicle-population-data

# %%
ev_pop_data.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
ev_pop_data.shape
# Out:
# (150482, 17)

# %%
#Month on month electric vehicle data 
ev_pop_per_month = pd.read_csv('datasets/Electric_Vehicle_Population_Size_History.csv')
#https://catalog.data.gov/dataset/electric-vehicle-population-size-history

# %%
ev_pop_per_month.head(100)
# Out:
#                  Date  Plug-In Hybrid Electric Vehicle (PHEV) Count  \
# 0     January 31 2017                                          7687
# 1    February 28 2017                                          7888
# 2       March 31 2017                                          8092
# 3       April 30 2017                                          8286
# 4         May 31 2017                                          8497
# ..                ...                                           ...
# 76        May 31 2023                                         31651
# 77       June 30 2023                                         32497
# 78       July 31 2023                                         33081
# 79     August 31 2023                                         33864
# 80  September 30 2023                                         34434
#
#     Battery Electric Vehicle (BEV) Count  Electric Vehicle (EV) Total
# 0                                  14738                        22425
# ...

# %%
#Washington Car Population History Counties
cars = pd.read_csv('datasets/Electric_Vehicle_Population_Size_History_By_County.csv')
#https://catalog.data.gov/dataset/electric-vehicle-population-size-history-by-county

# %%
#Filtering for just Washington
cars = cars[cars.State == 'WA']

# %%
cars.head()
# Out:
#             Date        County State Vehicle Primary Use  \
# 0   June 30 2020  Pend Oreille    WA           Passenger
# 1   July 31 2017      Columbia    WA               Truck
# 8    May 31 2021     Jefferson    WA               Truck
# 12  June 30 2019  Pend Oreille    WA               Truck
# 15   May 31 2021         Clark    WA               Truck
#
#     Battery Electric Vehicles (BEVs)  \
# 0                                  7
# 1                                  0
# 8                                  0
# 12                                 0
# 15                                 0
#
#     Plug-In Hybrid Electric Vehicles (PHEVs)  Electric Vehicle (EV) Total  \
# 0                                          6                           13
# 1                                          0                            0
# 8                                          0                            0
# 12                                         0                            0
# ...

# %%
cars = df.sort_values(by='Date')
cars.head(30)
# Out:
#                 Date       County State Vehicle Primary Use  \
# 18171  April 30 2017        Mason    WA               Truck
# 5486   April 30 2017       Yakima    WA           Passenger
# 9461   April 30 2017     Thurston    WA               Truck
# 3283   April 30 2017     Okanogan    WA           Passenger
# 5779   April 30 2017     Columbia    WA           Passenger
# 15129  April 30 2017     San Juan    WA               Truck
# 8943   April 30 2017    Klickitat    WA           Passenger
# 5054   April 30 2017  Walla Walla    WA           Passenger
# 9571   April 30 2017        Grant    WA               Truck
# 18719  April 30 2017        Grant    WA           Passenger
# 18996  April 30 2017     Skamania    WA               Truck
# 7559   April 30 2017    Jefferson    WA               Truck
# 10864  April 30 2017    Wahkiakum    WA               Truck
# 17172  April 30 2017      Whatcom    WA               Truck
# 8518   April 30 2017       Island    WA               Truck
# ...

# %%
cars.County.value_counts()
# Out:
# Mason           162
# Snohomish       162
# Adams           162
# Lincoln         162
# Grays Harbor    162
# Pierce          162
# Garfield        162
# Douglas         162
# Kitsap          162
# Kittitas        162
# Clark           162
# Franklin        162
# Stevens         162
# Spokane         162
# Cowlitz         162
# Asotin          162
# King            162
# Pacific         162
# Ferry           162
# Benton          162
# Yakima          162
# Skamania        162
# Thurston        162
# Okanogan        162
# Columbia        162
# San Juan        162
# Klickitat       162
# Walla Walla     162
# Grant           162
# Jefferson       162
# Clallam         162
# Wahkiakum       162
# Whatcom         162
# Island          162
# Skagit          162
# Whitman         162
# Chelan          162
# Lewis           162
# Pend Oreille    162
# Name: County, dtype: int64

# %%
fuel_stations = pd.read_csv('datasets/alt_fuel_stations.csv')
#https://afdc.energy.gov/stations/#/analyze
fuel_stations.head()
# Out:
# /var/folders/v1/kyy1qs715rbg2rqbmr3z3rb40000gn/T/ipykernel_9714/3849247855.py:1: DtypeWarning: Columns (14,15,16,20,31,33,34,39,41,43,46,49,52,57,58,59,60,61,62,65,67,69,70,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   fuel_stations = pd.read_csv('datasets/alt_fuel_stations.csv')
#   Fuel Type Code                                Station Name  \
# 0            CNG                  Arkansas Oklahoma Gas Corp
# 1            CNG  Clean Energy - Logan International Airport
# 2            CNG      Clean Energy - Everett - National Grid
# 3            CNG   Clean Energy - Greenpoint - National Grid
# 4            CNG                    Canarsie - National Grid
#
#         Street Address                            Intersection Directions  \
# 0    2100 S Waldron Rd                                                NaN
# 1  1000 Cottage St Ext  From Route 1, take the first exit after Callah...
# ...
